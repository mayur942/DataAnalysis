# %%
import pandas as pd
df = pd.read_csv("Movie-Ratings.csv")
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %% [markdown]
# # 1)list of top 10 movie (ascending order) in terms of budget

# %%
df.sort_values('Budget (million $)').head(10)
# Out:
#                      Film    Genre  Rotten Tomatoes Ratings %  \
# 154             Greenberg   Comedy                         75
# 201             Jane Eyre  Romance                         85
# 356              Soul Men   Comedy                         45
# 185        I'm Still Here   Comedy                         52
# 474     The Spy Next Door   Action                         13
# 487        The Uninvited     Drama                         31
# 287    Our Family Wedding   Comedy                         14
# 539          When in Rome   Comedy                         15
# 292  Paranormal Activity    Horror                         82
# 128             Fireproof    Drama                         40
#
#      Audience Ratings %  Budget (million $)  Year of release
# 154                  40                   0             2010
# 201                  77                   0             2011
# 356                  42                   0             2008
# ...

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# #  2)list of top 10 movie(descending order) in terms of budget

# %%
df.sort_values('Budget (million $)', ascending=False).head(10)
# Out:
#                                             Film      Genre  \
# 304     Pirates of the Caribbean: At World's End     Action
# 360                                 Spider-Man 3     Action
# 303  Pirates of the Caribbean: On Stranger Tides     Action
# 167      Harry Potter and the Half-Blood Prince   Adventure
# 33                                       Avatar      Action
# 314                            Quantum of Solace     Action
# 501         Transformers: Revenge of the Fallen      Action
# 327                                   Robin Hood     Action
# 5                                           2012     Action
# 400     The Chronicles of Narnia: Prince Caspian     Action
#
#      Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# 304                         45                  74                 300
# 360                         61                  54                 258
# 303                         34                  61                 250
# ...

# %% [markdown]
# # 3) which genre is the best in terms of price budget

# %%
gen = df.groupby('Genre').mean()

# %%
gen[gen['Budget (million $)']== gen['Budget (million $)'].max()]['Budget (million $)']
# Out:
# Genre
# Action    84.62987
# Name: Budget (million $), dtype: float64

# %% [markdown]
# # 4) distribution(graph) of audience rating

# %%
sns.distplot(df['Audience Ratings %'])

# %% [markdown]
# # 5) distribution(graph) of critics rating (rotten tomato)

# %%
sns.distplot(df['Rotten Tomatoes Ratings %'])

# %% [markdown]
# # 6) distribution of budget

# %%
sns.distplot(df['Budget (million $)'])

# %% [markdown]
# # 7) distribution of critics rating

# %%
sns.distplot(df['Rotten Tomatoes Ratings %'])

# %% [markdown]
# # 8) distribution of audience rating

# %%
sns.distplot(df['Audience Ratings %'])

# %% [markdown]
# # 9) histogram of critics rating

# %%
sns.distplot(df['Rotten Tomatoes Ratings %'],kde=False)

# %% [markdown]
# # 10) histogram of audience rating

# %%
sns.distplot(df['Audience Ratings %'],kde=False)

# %% [markdown]
# # 11) show the total count of all the different genre present in the dataset

# %%
df ['Genre'].value_counts()
# Out:
# Comedy       172
# Action       154
# Drama        101
# Horror        49
# Thriller      36
# Adventure     29
# Romance       18
# Name: Genre, dtype: int64

# %% [markdown]
# # 12) show the graph of rating based on genre

# %%
sns.barplot(x='Genre',y='Rotten Tomatoes Ratings %',data = df)

# %% [markdown]
# # 13) scatter plot of critics rating vs audience rating

# %%
sns.jointplot(x='Rotten Tomatoes Ratings %',y='Audience Ratings %',data=df,kind='scatter')

# %% [markdown]
# # 14) box plot based on genre and critics rating

# %%
sns.boxplot(x='Genre',y='Rotten Tomatoes Ratings %',data=df,palette='rainbow')

# %% [markdown]
# # 15) box plot based on genre and audience rating

# %%
sns.boxplot(x='Genre',y='Audience Ratings %',data=df,palette='rainbow')

# %% [markdown]
# # 16) pairplot of the whole data set

# %%
sns.pairplot(df,palette='rainbow')

# %% [markdown]
# # 17)  histogram of  top 10 movie(descending order) in terms of budget

# %%
des = df.sort_values("Budget (million $)",ascending=False).head(10)
sns.distplot(des['Budget (million $)'],kde=False,bins=10)

# %% [markdown]
# # 18)  histogram of  top 10 movie(ascending order) in terms of budget

# %%
des = df.sort_values("Budget (million $)").head(10)
sns.distplot(des['Budget (million $)'],kde=False,bins=10)

# %% [markdown]
# # 19) Joint Plot of critics rating and audience rating (with type as hexagonal)

# %%
sns.jointplot(x='Rotten Tomatoes Ratings %',y='Audience Ratings %',data=df,kind='hex')

# %% [markdown]
# # 20) Joint plot of budget vs genre (type as scatter)

# %%
sns.swarmplot(x='Genre', y='Budget (million $)', data=df)
